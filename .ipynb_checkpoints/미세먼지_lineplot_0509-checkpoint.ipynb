# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib import font_manager,rc

font_name=font_manager.FontProperties(fname="C:/windows/Fonts/malgun.ttf").get_name()
rc('font',family=font_name)

mpl.rcParams['axes.unicode_minus'] = False

plt.rcParams["figure.figsize"] = (14,6) #set size of Graph

# %%
cd E:미세먼지
# Out:
# E:\미세먼지

# %%
mise = pd.read_csv('mise.csv',encoding = 'ms949')

# %%
mise.head()
# Out:
#    Unnamed: 0  PM10  PM25      지역        측정일시  시도    연도  월  일  시간
# 0           0  47.0  38.0  강원 강릉시  2016010101  강원  2016  1  1   1
# 1           1  51.0  43.0  강원 강릉시  2016010102  강원  2016  1  1   2
# 2           2  52.0  44.0  강원 강릉시  2016010103  강원  2016  1  1   3
# 3           3  45.0  38.0  강원 강릉시  2016010104  강원  2016  1  1   4
# 4           4  43.0  37.0  강원 강릉시  2016010105  강원  2016  1  1   5

# %%
mise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8990691 entries, 0 to 8990690
# Data columns (total 10 columns):
# Unnamed: 0    int64
# PM10          float64
# PM25          float64
# 지역            object
# 측정일시          int64
# 시도            object
# 연도            int64
# 월             int64
# 일             int64
# 시간            int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 685.9+ MB

# %%
mise1 = mise[mise['시도'].values != '강원']
mise1 = mise1[mise1['시도'].values != '경기']
mise1 = mise1[mise1['시도'].values != '경남']
mise1 = mise1[mise1['시도'].values != '경북']
mise1 = mise1[mise1['시도'].values != '전북']
mise1 = mise1[mise1['시도'].values != '전남']
mise1 = mise1[mise1['시도'].values != '충남']
mise1 = mise1[mise1['시도'].values != '충북']
mise1 = mise1[mise1['시도'].values != '제주']
mise1 = mise1[mise1['시도'].values != '세종']

# %%
mise1.head()
# Out:
#         Unnamed: 0  PM10  PM25      지역        측정일시  시도    연도  월  일  시간
# 290472      290472  62.0  41.0  광주 광산구  2016010101  광주  2016  1  1   1
# 290473      290473  61.0  43.0  광주 광산구  2016010102  광주  2016  1  1   2
# 290474      290474  64.0  46.0  광주 광산구  2016010103  광주  2016  1  1   3
# 290475      290475  60.0  42.0  광주 광산구  2016010104  광주  2016  1  1   4
# 290476      290476  56.0  42.0  광주 광산구  2016010105  광주  2016  1  1   5

# %%
mise11 = mise1.groupby(['시도','시간']).mean()

# %%
mise11.head(3)
# Out:
#          Unnamed: 0       PM10       PM25          측정일시           연도  \
# 시도 시간
# 광주 1   4.327284e+06  41.071429  24.728655  2.017066e+09  2016.999088
#    2   4.327285e+06  40.201895  24.593454  2.017066e+09  2016.999088
#    3   4.327286e+06  39.454152  24.298726  2.017066e+09  2016.999088
#
#               월          일
# 시도 시간
# 광주 1   6.521898  15.732664
#    2   6.521898  15.732664
#    3   6.521898  15.732664

# %%
mise11.reset_index(['시도','시간'],inplace=True)

# %%
mise11.head(3)
# Out:
#    시도  시간    Unnamed: 0       PM10       PM25          측정일시           연도  \
# 0  광주   1  4.327284e+06  41.071429  24.728655  2.017066e+09  2016.999088
# 1  광주   2  4.327285e+06  40.201895  24.593454  2.017066e+09  2016.999088
# 2  광주   3  4.327286e+06  39.454152  24.298726  2.017066e+09  2016.999088
#
#           월          일
# 0  6.521898  15.732664
# 1  6.521898  15.732664
# 2  6.521898  15.732664

# %%
mise11.to_csv('miseSummary.csv',encoding = 'ms949')

# %%
mise11 = pd.read_csv('miseSummary.csv',encoding ='ms949')

# %%
mise11.head()
# Out:
#    Unnamed: 0  시도  시간  Unnamed: 0.1       PM10       PM25          측정일시  \
# 0           0  광주   1  4.327284e+06  41.071429  24.728655  2.017066e+09
# 1           1  광주   2  4.327285e+06  40.201895  24.593454  2.017066e+09
# 2           2  광주   3  4.327286e+06  39.454152  24.298726  2.017066e+09
# 3           3  광주   4  4.327287e+06  38.894292  24.216172  2.017066e+09
# 4           4  광주   5  4.327288e+06  38.183747  23.941211  2.017066e+09
#
#             연도         월          일
# 0  2016.999088  6.521898  15.732664
# 1  2016.999088  6.521898  15.732664
# 2  2016.999088  6.521898  15.732664
# 3  2016.999088  6.521898  15.732664
# 4  2016.999088  6.521898  15.732664

# %%
plt.title('미세요약통계량')
plt.subplot(2,1,1)
ax = sns.lineplot(x="시간", y="PM10",hue='시도',data=mise11)
ax.legend(bbox_to_anchor=(1.1,1.05))
plt.axvline(10)
plt.axvline(11)
plt.subplot(2,1,2)
ax = sns.lineplot(x="시간", y="PM25",hue='시도',data=mise11)
ax.legend(bbox_to_anchor=(1.1,1.05))
plt.axvline(10)
plt.axvline(11)

# %%
plt.title('미세요약통계량')
ax = sns.lineplot(x="시간", y="PM25",hue='시도',data=mise1)
ax.legend(bbox_to_anchor=(1.1,1.05))
plt.axvline(10)
plt.axvline(11)

# %%
mise2=mise1

# %%
mise2.head()
# Out:
#         Unnamed: 0  PM10  PM25      지역        측정일시  시도    연도  월  일  시간
# 290472      290472  62.0  41.0  광주 광산구  2016010101  광주  2016  1  1   1
# 290473      290473  61.0  43.0  광주 광산구  2016010102  광주  2016  1  1   2
# 290474      290474  64.0  46.0  광주 광산구  2016010103  광주  2016  1  1   3
# 290475      290475  60.0  42.0  광주 광산구  2016010104  광주  2016  1  1   4
# 290476      290476  56.0  42.0  광주 광산구  2016010105  광주  2016  1  1   5

# %%
mise2 = mise2.groupby(['시도','연도','시간']).mean()

# %%
mise2.head()
# Out:
#               Unnamed: 0       PM10       PM25          측정일시         월  \
# 시도 연도   시간
# 광주 2016 1   1.357489e+06  40.723294  24.318236  2.016067e+09  6.513661
#         2   1.357490e+06  39.661157  24.259843  2.016067e+09  6.513661
#         3   1.357491e+06  38.909703  23.687008  2.016067e+09  6.513661
#         4   1.357492e+06  38.800674  23.717323  2.016067e+09  6.513661
#         5   1.357493e+06  38.741501  23.612446  2.016067e+09  6.513661
#
#                     일
# 시도 연도   시간
# 광주 2016 1   15.756831
#         2   15.756831
#         3   15.756831
#         4   15.756831
#         5   15.756831

# %%
mise2.reset_index(['시도','연도','시간'],inplace=True)

# %%
mise2.head()
# Out:
#    시도    연도  시간    Unnamed: 0       PM10       PM25          측정일시         월  \
# 0  광주  2016   1  1.357489e+06  40.723294  24.318236  2.016067e+09  6.513661
# 1  광주  2016   2  1.357490e+06  39.661157  24.259843  2.016067e+09  6.513661
# 2  광주  2016   3  1.357491e+06  38.909703  23.687008  2.016067e+09  6.513661
# 3  광주  2016   4  1.357492e+06  38.800674  23.717323  2.016067e+09  6.513661
# 4  광주  2016   5  1.357493e+06  38.741501  23.612446  2.016067e+09  6.513661
#
#            일
# 0  15.756831
# 1  15.756831
# 2  15.756831
# 3  15.756831
# 4  15.756831

# %%
mise10 = mise2[mise2['시간']==10]

# %%
mise11 = mise2[mise2['시간']==11]

# %%
mise10.head()
# Out:
#      시도    연도  시간    Unnamed: 0       PM10       PM25          측정일시         월  \
# 9    광주  2016  10  1.357498e+06  47.108058  27.217270  2.016067e+09  6.513661
# 33   광주  2017  10  4.288505e+06  47.605410  28.278174  2.017067e+09  6.526027
# 57   광주  2018  10  7.344013e+06  46.100909  26.714644  2.018067e+09  6.526027
# 81   대구  2016  10  1.388051e+06  52.628803  30.368174  2.016067e+09  6.552114
# 105  대구  2017  10  4.361504e+06  52.709366  30.376516  2.017067e+09  6.526027
#
#              일
# 9    15.756831
# 33   15.720548
# 57   15.720548
# 81   15.758535
# 105  15.720548

# %%
plt.rcParams["figure.figsize"] = (10,10) #set size of Graph
plt.subplot(2,2,1)
ax1 = sns.lineplot(x="연도", y="PM10",data=mise10)
plt.subplot(2,2,2)
ax1 = sns.lineplot(x="연도", y="PM25",data=mise10)
plt.subplot(2,2,1)
plt.title('연도별 10시11시 미세먼지 농도')
ax2 = sns.lineplot(x="연도", y="PM10",data=mise11,c='y')
plt.subplot(2,2,2)
plt.title('연도별 10시11시 초미세먼지 농도')
ax2 = sns.lineplot(x="연도", y="PM25",data=mise11,c='y')
# Out:
# C:\Users\dydeh\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# C:\Users\dydeh\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# C:\Users\dydeh\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# C:\Users\dydeh\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# C:\Users\dydeh\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# C:\Users\dydeh\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
