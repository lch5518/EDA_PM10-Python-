# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd
# Out:
# C:\Users\user

# %%
directory = 'D:\4학년1학기\탐색적데이터분석\미세먼지_통계량.csv'

lch=pd.read_csv('미세먼지_통계량.csv',engine='python')

# %%
lch.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2   PM10             PM10.1  \
# 0        NaN        NaN        NaN  count               mean
# 1         시도         연도          월    NaN                NaN
# 2         강원       2016         01   31.0  93.12903225806451
# 3         강원       2016         02   29.0  76.41379310344827
# 4         강원       2016         03   31.0   97.7741935483871
#
#                PM10.2 PM10.3 PM10.4 PM10.5 PM10.6 PM10.7   PM25  \
# 0                 std    min    25%    50%    75%    max  count
# 1                 NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  28.772373248753592   42.0   78.5   94.0  100.0  180.0   31.0
# 3  25.600665785677347   38.0   56.0   72.0   96.0  121.0   29.0
# 4  27.585877639859316   51.0   80.5   97.0  121.5  141.0   31.0
#
#               PM25.1              PM25.2 PM25.3 PM25.4 PM25.5 PM25.6 PM25.7
# 0               mean                 std    min    25%    50%    75%    max
# ...

# %%
lch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 19 columns):
# Unnamed: 0    609 non-null object
# Unnamed: 1    609 non-null object
# Unnamed: 2    609 non-null object
# PM10          609 non-null object
# PM10.1        609 non-null object
# PM10.2        609 non-null object
# PM10.3        609 non-null object
# PM10.4        609 non-null object
# PM10.5        609 non-null object
# PM10.6        609 non-null object
# PM10.7        609 non-null object
# PM25          609 non-null object
# PM25.1        609 non-null object
# PM25.2        609 non-null object
# PM25.3        609 non-null object
# PM25.4        609 non-null object
# PM25.5        609 non-null object
# PM25.6        609 non-null object
# PM25.7        609 non-null object
# dtypes: object(19)
# memory usage: 90.6+ KB

# %%
miseDfLCH = lch.iloc[:,[0,1,2,10,18]]

miseDfLCH.rename( columns={'Unnamed: 0':'시도'}, inplace=True )
miseDfLCH.rename( columns={'Unnamed: 1':'연도'}, inplace=True )
miseDfLCH.rename( columns={'Unnamed: 2':'월'}, inplace=True )

miseDfLCH0 = miseDfLCH.drop([0,1],0)

miseDfLCH0 = miseDfLCH0.reset_index(drop=True)

# %%
miseDfLCH0.head()
# Out:
#    시도    연도   월 PM10.7 PM25.7
# 0  강원  2016  01  180.0  154.0
# 1  강원  2016  02  121.0   95.0
# 2  강원  2016  03  141.0  106.0
# 3  강원  2016  04  240.0   96.0
# 4  강원  2016  05  217.0   85.0

# %%
miseDfLCH1 = miseDfLCH0.groupby(by=['시도','연도','월']).max()

# %%
miseDfLCH1.head()
# Out:
#    시도    연도   월 PM10.7 PM25.7
# 0  강원  2016  01  180.0  154.0
# 1  강원  2016  02  121.0   95.0
# 2  강원  2016  03  141.0  106.0
# 3  강원  2016  04  240.0   96.0
# 4  강원  2016  05  217.0   85.0

# %%
miseDfLCH1.reset_index(inplace=True)

# %%
miseDfLCH1.head()
# Out:
#    시도    연도   월 PM10.7 PM25.7   미세먼지  초미세먼지
# 0  강원  2016  01  180.0  154.0  180.0  154.0
# 1  강원  2016  02  121.0   95.0  121.0   95.0
# 2  강원  2016  03  141.0  106.0  141.0  106.0
# 3  강원  2016  04  240.0   96.0  240.0   96.0
# 4  강원  2016  05  217.0   85.0  217.0   85.0

# %%
data0 = miseDfLCH1['PM10.7']
data1 = miseDfLCH1['PM25.7']

miseDfLCH1['미세먼지'] = data0.astype(float)
miseDfLCH1['초미세먼지'] = data1.astype(float)

miseDfLCH1=miseDfLCH1.drop('PM10.7',1)
miseDfLCH1=miseDfLCH1.drop('PM25.7',1)

# %%
miseDfLCH1.head()
# Out:
#    시도    연도   월   미세먼지  초미세먼지
# 0  강원  2016  01  180.0  154.0
# 1  강원  2016  02  121.0   95.0
# 2  강원  2016  03  141.0  106.0
# 3  강원  2016  04  240.0   96.0
# 4  강원  2016  05  217.0   85.0

# %%
test
# Out:
#    시도    연도   월  PM10.7 PM25.7
# 0  강원  2016  01   180.0  154.0
# 1  강원  2016  02   121.0   95.0
# 2  강원  2016  03   141.0  106.0
# 3  강원  2016  04   240.0   96.0
# 4  강원  2016  05   217.0   85.0

# %%
sns.boxplot(x='시도',y='미세먼지',hue='연도',data=miseDfLCH1)

# %%
import matplotlib as mpl
#from matplotlib import font_manager,rc
font_name=font_manager.FontProperties(fname="C:/windows/Fonts/malgun.ttf").get_name()
rc('font',family=font_name)

mpl.rcParams['axes.unicode_minus'] = False

plt.rcParams["figure.figsize"] = (14,4) #set size of Graph

sns.boxplot(x='시도',y='PM10.7',data=miseDfLCH1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ff10648cd930> in <module>()
#       8 plt.rcParams["figure.figsize"] = (14,4) #set size of Graph
#       9
# ---> 10 sns.boxplot(x='시도',y='PM10.7',data=miseDfLCH1)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
#     545         self.annotate_axes(ax)
#     546         if self.orient == "h":
#
# ...
