# %%
import myclt2

myclt2.plt.subplot(131)
myclt2.gamclt(5,1,0.5)
myclt2.plt.subplot(132)
myclt2.gamclt(10,1,0.5)
myclt2.plt.subplot(133)
myclt2.gamclt(20,1,0.5)

# %%
n,a,b = input("Enter(표본크기, 알파, 베타) :").split()
print(n,a,b)
# Out:
# Enter(표본크기, 알파, 베타) :10 1 0.5
# 10 1 0.5
